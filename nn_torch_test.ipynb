# %%
import numpy as np
import pandas as pd


import os
for dirname, _, filenames in os.walk('./Data/london'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./Data/london/household_MAC001926.csv
# ./Data/london/household_MAC004686.csv
# ./Data/london/household_MAC002591.csv
# ./Data/london/household_MAC003857.csv
# ./Data/london/household_MAC000386.csv
# ./Data/london/household_MAC001098.csv
# ./Data/london/household_MAC000392.csv
# ./Data/london/household_MAC002585.csv
# ./Data/london/household_MAC003843.csv
# ./Data/london/household_MAC004692.csv
# ./Data/london/household_MAC001932.csv
# ./Data/london/household_MAC004862.csv
# ./Data/london/household_MAC004876.csv
# ./Data/london/household_MAC002234.csv
# ./Data/london/household_MAC004645.csv
# ./Data/london/household_MAC000423.csv
# ./Data/london/household_MAC000345.csv
# ./Data/london/household_MAC004123.csv
# ./Data/london/household_MAC002552.csv
# ./Data/london/household_MAC003894.csv
# ./Data/london/household_MAC004137.csv
# ./Data/london/household_MAC003658.csv
# ./Data/london/household_MAC002546.csv
# ./Data/london/household_MAC005229.csv
# ./Data/london/household_MAC003880.csv
# ...

# %%
test_file = './Data/london/household_MAC000002.csv'

df = pd.read_csv(test_file, index_col=0)
# rename KWH/hh (per half hour) to KWH
df.rename(columns={'KWH/hh (per half hour) ': 'KWH'}, inplace=True)

# %%
df.head()
# Out:
#        LCLid stdorToU             DateTime  KWH timeOfDay
# 0  MAC000002      Std  2012-10-12 00:30:00  0.0  00:30:00
# 1  MAC000002      Std  2012-10-12 01:00:00  0.0  01:00:00
# 2  MAC000002      Std  2012-10-12 01:30:00  0.0  01:30:00
# 3  MAC000002      Std  2012-10-12 02:00:00  0.0  02:00:00
# 4  MAC000002      Std  2012-10-12 02:30:00  0.0  02:30:00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
plt.figure(figsize = (30,9))
plt.plot(df[['KWH']])
plt.xticks(range(0,df.shape[0],500),df['DateTime'].loc[::500],rotation=45)
plt.title("Example household",fontsize=18, fontweight='bold')
plt.xlabel('Date',fontsize=18)
plt.ylabel('KWH',fontsize=18)
plt.show()

# %%
weahter_file = './Data/London_weather_2011-2014.csv'

df_weather = pd.read_csv(weahter_file, index_col=0)

# %%
df_weather.head()
# Out:
#               DateTime  Temperature_C  Dew_Point_C  Humidity_%  Speed_kmh  \
# 0  2011-01-01 00:00:00           5.61         3.78       88.00       4.29
# 1  2011-01-01 00:15:00           5.61         3.78       88.00       3.22
# 2  2011-01-01 00:30:00           5.61         3.67       87.33       2.95
# 3  2011-01-01 00:45:00           5.61         3.61       87.00       7.18
# 4  2011-01-01 01:00:00           5.50         3.50       87.00       5.85
#
#    Gust_kmh  Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm   UV  Solar_w/m2
# 0      6.60       1025.06             0.0              0.0  0.0         2.0
# 1      4.99       1025.06             0.0              0.0  0.0         2.0
# 2      5.79       1025.06             0.0              0.0  0.0         2.0
# 3      9.44       1025.06             0.0              0.0  0.0         2.0
# 4      7.56       1025.06             0.0              0.0  0.0         2.0

# %%
print(df["DateTime"].min())
print(df["DateTime"].max())

# get the weather data from 2011 to 2014
df_weather = df_weather[df_weather['DateTime']>='2012-10-11']
df_weather = df_weather[df_weather['DateTime']<='2014-02-29']
# Out:
# 2012-10-12 00:30:00
# 2014-02-28 00:00:00

# %%
df_weather
# Out:
#                    DateTime  Temperature_C  Dew_Point_C  Humidity_%  \
# 62304   2012-10-11 00:00:00          10.22         5.17       71.00
# 62305   2012-10-11 00:15:00          10.22         5.39       72.00
# 62306   2012-10-11 00:30:00          10.15         5.32       72.00
# 62307   2012-10-11 00:45:00          10.07         5.24       72.00
# 62308   2012-10-11 01:00:00          10.00         5.24       72.33
# ...                     ...            ...          ...         ...
# 110875  2014-02-28 22:45:00           4.50         4.06       97.00
# 110876  2014-02-28 23:00:00           4.54         4.10       97.00
# 110877  2014-02-28 23:15:00           4.50         3.98       96.33
# 110878  2014-02-28 23:30:00           4.43         3.87       96.00
# 110879  2014-02-28 23:45:00           4.50         3.98       96.33
#
#         Speed_kmh  Gust_kmh  Pressure_hPa  Precip_Rate_mm  Precip_Accum_mm  \
# ...

# %%
energy = df[['KWH']]
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24158 entries, 0 to 24157
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KWH     24157 non-null  float64
# dtypes: float64(1)
# memory usage: 377.5 KB

# %%
# drop the NaN values
energy = energy.dropna()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
energy['KWH'] = scaler.fit_transform(energy['KWH'].values.reshape(-1,1))

# %%
def split_data(energy_kwh, lookback):
    data_raw = energy_kwh.to_numpy() # convert to numpy array
    data = []
    
    # create all possible sequences of length seq_len
    for index in range(len(data_raw) - lookback): 
        data.append(data_raw[index: index + lookback])
    
    data = np.array(data);
    test_set_size = int(np.round(0.2*data.shape[0]));
    train_set_size = data.shape[0] - (test_set_size);
    
    x_train = data[:train_set_size,:-1,:]
    y_train = data[:train_set_size,-1,:]
    
    x_test = data[train_set_size:,:-1]
    y_test = data[train_set_size:,-1,:]
    
    return [x_train, y_train, x_test, y_test]

# %%
lookback = 20 # choose sequence length
x_train, y_train, x_test, y_test = split_data(energy, lookback)
print('x_train.shape = ',x_train.shape)
print('y_train.shape = ',y_train.shape)
print('x_test.shape = ',x_test.shape)
print('y_test.shape = ',y_test.shape)
# Out:
# x_train.shape =  (19310, 19, 1)
# y_train.shape =  (19310, 1)
# x_test.shape =  (4827, 19, 1)
# y_test.shape =  (4827, 1)

# %%
import torch
import torch.nn as nn

x_train = torch.from_numpy(x_train).type(torch.Tensor)
x_test = torch.from_numpy(x_test).type(torch.Tensor)
y_train_lstm = torch.from_numpy(y_train).type(torch.Tensor)
y_test_lstm = torch.from_numpy(y_test).type(torch.Tensor)
y_train_gru = torch.from_numpy(y_train).type(torch.Tensor)
y_test_gru = torch.from_numpy(y_test).type(torch.Tensor)

# %%
input_dim = 1
hidden_dim = 64
num_layers = 3
output_dim = 1
num_epochs = 100

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_layers, output_dim):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).requires_grad_()
        out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
        out = self.fc(out[:, -1, :]) 
        return out

# %%
model = LSTM(input_dim=input_dim, hidden_dim=hidden_dim, output_dim=output_dim, num_layers=num_layers)
criterion = torch.nn.MSELoss(reduction='sum')
optimiser = torch.optim.Adam(model.parameters(), lr=0.07)

# %%
import time

hist = np.zeros(num_epochs)
start_time = time.time()
lstm = []

for i in range(num_epochs):
    y_train_pred = model(x_train)

    loss = criterion(y_train_pred, y_train_lstm)
    print("Epoch ", i, "MSE: ", loss.item())
    hist[i] = loss.item()

    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
    
training_time = time.time()-start_time
print(f"Training time: {training_time}")
# Out:
# Epoch  0 MSE:  12922.576171875
# Epoch  1 MSE:  3814.52294921875
# Epoch  2 MSE:  8971.1435546875
# Epoch  3 MSE:  2527.3046875
# Epoch  4 MSE:  4547.84619140625
# Epoch  5 MSE:  2544.144287109375
# Epoch  6 MSE:  532.0785522460938
# Epoch  7 MSE:  1432.1474609375
# Epoch  8 MSE:  539.906982421875
# Epoch  9 MSE:  580.4185180664062
# Epoch  10 MSE:  773.6767578125
# Epoch  11 MSE:  661.5485229492188
# Epoch  12 MSE:  508.5589599609375
# Epoch  13 MSE:  495.6155700683594
# Epoch  14 MSE:  572.7088012695312
# Epoch  15 MSE:  604.5912475585938
# Epoch  16 MSE:  557.29931640625
# Epoch  17 MSE:  500.2414245605469
# Epoch  18 MSE:  484.0102233886719
# Epoch  19 MSE:  502.0575866699219
# Epoch  20 MSE:  524.3303833007812
# Epoch  21 MSE:  529.7363891601562
# Epoch  22 MSE:  516.53271484375
# Epoch  23 MSE:  496.7414855957031
# Epoch  24 MSE:  484.48785400390625
# Epoch  25 MSE:  486.0938720703125
# Epoch  26 MSE:  496.9349670410156
# Epoch  27 MSE:  506.4074401855469
# ...

# %%
predict = pd.DataFrame(scaler.inverse_transform(y_train_pred.detach().numpy()))
original = pd.DataFrame(scaler.inverse_transform(y_train_lstm.detach().numpy()))

# %%
import seaborn as sns
sns.set_style("darkgrid")    

fig = plt.figure()
fig.subplots_adjust(hspace=0.2, wspace=0.2)

plt.subplot(1, 2, 1)
ax = sns.lineplot(x = original.index, y = original[0], label="Data", color='royalblue', alpha=0.8, )
ax = sns.lineplot(x = predict.index, y = predict[0], label="Training Prediction (LSTM)", color='tomato')
ax.set_title('Energy consumption', size = 14, fontweight='bold')
ax.set_xlabel("Days", size = 14)
ax.set_ylabel("Energy (KWH)", size = 14)
ax.set_xticklabels('', size=10)


plt.subplot(1, 2, 2)
ax = sns.lineplot(data=hist, color='royalblue')
ax.set_xlabel("Epoch", size = 14)
ax.set_ylabel("Loss", size = 14)
ax.set_title("Training Loss", size = 14, fontweight='bold')
fig.set_figheight(7)
fig.set_figwidth(30)

# %%
import math, time
from sklearn.metrics import mean_squared_error

# make predictions
y_test_pred = model(x_test)

# invert predictions
y_train_pred = scaler.inverse_transform(y_train_pred.detach().numpy())
y_train = scaler.inverse_transform(y_train_lstm.detach().numpy())
y_test_pred = scaler.inverse_transform(y_test_pred.detach().numpy())
y_test = scaler.inverse_transform(y_test_lstm.detach().numpy())

# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(y_train[:,0], y_train_pred[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test[:,0], y_test_pred[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
lstm.append(trainScore)
lstm.append(testScore)
lstm.append(training_time)
# Out:
# Train Score: 0.24 RMSE
# Test Score: 0.28 RMSE
